# %%
import json

# %% [markdown]
# # SelfCk-1gm

# %% [markdown]
# ## temperature=0.1

# %%
t=0
f=0
with open('baselines/SelfCk-1gm/wice/13Bllama/result_1.json') as file:
    for line in file:
        data = json.loads(line)
        claim = data['claim']
        answer = data['sent_scores_mqag']
        score = answer['doc_level']['avg_neg_logprob']#avg_max_neg_logprob
        #print(score)
        with open('llama2_data/wice+0.1/dataset_0.1.jsonl') as file1:  
            for line1 in file1:
#                 data1 = json.loads(line1)
#                 q = data1[0]['messages'][0]['content']
#                 claim1 = q.split('Claim: ')[1].split('Reference:')[0]
                claim1=line1.split(" Reference: ")[0].split("Claim: ")[1]
                if claim1.strip() == claim.strip():
                    #label=data1[0]['label']
                    label=line1.split("label: ")[1]
                    if 'true' in label: # hallucination
                        if score>=5: # hallucination
                            t+=1
                    else:# factual
                        if score<5: # factual
                            f+=1

# %%
num=242
print(t,t/(num-0))
print(f,f/(num-0))

all_num=num*2-0
FN=(num-0-t)/all_num  # FN:
print('FN',FN)

FP=(num-0-f)/all_num  # FP:
print('FP',FP)

TN=f/all_num  # TN:
print('TN',TN)

TP=t/all_num  # TP:
print('TP',TP)

Accuracy=TN+TP
print('Accuracy=',Accuracy)
Precision=TP/(TP+FP)
print('Precision=',Precision)
Recall=TP/(TP+FN)
print('Recall=',Recall)
F1=2*TP/(2*TP+FP+FN)
print('F1 score=',F1)
# Out:
# 57 0.23553719008264462
# 187 0.7727272727272727
# FN 0.3822314049586777
# FP 0.11363636363636363
# TN 0.38636363636363635
# TP 0.11776859504132231
# Accuracy= 0.5041322314049587
# Precision= 0.5089285714285714
# Recall= 0.23553719008264462
# F1 score= 0.3220338983050847

# %%
num=348/2
print(t,t/num)
print(f,f/num)

all_num=num*2
FN=(num-t)/all_num  # FN:
print('FN',FN)

FP=(num-f)/all_num  # FP:
print('FP',FP)

TN=f/all_num  # TN:
print('TN',TN)

TP=t/all_num  # TP:
print('TP',TP)

Accuracy=TN+TP
print('Accuracy=',Accuracy)
Precision=TP/(TP+FP)
print('Precision=',Precision)
Recall=TP/(TP+FN)
print('Recall=',Recall)
F1=2*TP/(2*TP+FP+FN)
print('F1 score=',F1)
# Out:
# 26 0.14942528735632185
# 148 0.8505747126436781
# FN 0.42528735632183906
# FP 0.07471264367816093
# TN 0.42528735632183906
# TP 0.07471264367816093
# Accuracy= 0.5
# Precision= 0.5
# Recall= 0.14942528735632185
# F1 score= 0.2300884955752213

# %% [markdown]
# ## temperature=0.5

# %%
t=0
f=0
with open('baselines/SelfCk-1gm/climate/13Bllama/result_5.json') as file:
    for line in file:
        data = json.loads(line)
        claim = data['claim']
        answer = data['sent_scores_mqag']
        score = answer['doc_level']['avg_neg_logprob']#avg_max_neg_logprob
        #print(score)
        with open('llama2_data/climate+0.5/dataset_0.5.jsonl') as file1:  
            for line1 in file1:
#                 data1 = json.loads(line1)
#                 q = data1[0]['messages'][0]['content']
#                 claim1 = q.split('Claim: ')[1].split('Reference:')[0]
                claim1=line1.split(" Reference: ")[0].split("Claim: ")[1]
                if claim1.strip() == claim.strip():
                    #label=data1[0]['label']
                    label=line1.split("label: ")[1]
                    if 'true' in label: # hallucination
                        if score>=5: # hallucination
                            t+=1
                    else:# factual
                        if score<5: # factual
                            f+=1

# %%
num=177
print(t,t/(num-1))
print(f,f/(num-0))

all_num=num*2-1
FN=(num-1-t)/all_num  # FN:
print('FN',FN)

FP=(num-0-f)/all_num  # FP:
print('FP',FP)

TN=f/all_num  # TN:
print('TN',TN)

TP=t/all_num  # TP:
print('TP',TP)

Accuracy=TN+TP
print('Accuracy=',Accuracy)
Precision=TP/(TP+FP)
print('Precision=',Precision)
Recall=TP/(TP+FN)
print('Recall=',Recall)
F1=2*TP/(2*TP+FP+FN)
print('F1 score=',F1)
# Out:
# 129 0.7329545454545454
# 58 0.327683615819209
# FN 0.13314447592067988
# FP 0.3371104815864023
# TN 0.1643059490084986
# TP 0.3654390934844193
# Accuracy= 0.5297450424929179
# Precision= 0.5201612903225807
# Recall= 0.7329545454545454
# F1 score= 0.6084905660377358

# %%
num=442/2
print(t,t/num)
print(f,f/num)

all_num=num*2
FN=(num-t)/all_num  # FN:
print('FN',FN)

FP=(num-f)/all_num  # FP:
print('FP',FP)

TN=f/all_num  # TN:
print('TN',TN)

TP=t/all_num  # TP:
print('TP',TP)

Accuracy=TN+TP
print('Accuracy=',Accuracy)
Precision=TP/(TP+FP)
print('Precision=',Precision)
Recall=TP/(TP+FN)
print('Recall=',Recall)
F1=2*TP/(2*TP+FP+FN)
print('F1 score=',F1)
# Out:
# 52 0.23529411764705882
# 153 0.6923076923076923
# FN 0.38235294117647056
# FP 0.15384615384615385
# TN 0.34615384615384615
# TP 0.11764705882352941
# Accuracy= 0.4638009049773756
# Precision= 0.4333333333333333
# Recall= 0.23529411764705882
# F1 score= 0.30498533724340177

# %% [markdown]
# ## temperature=0.9

# %%
t=0
f=0
with open('baselines/SelfCk-1gm/climate/13Bllama/result_9.json') as file:
    for line in file:
        data = json.loads(line)
        claim = data['claim']
        answer = data['sent_scores_mqag']
        score = answer['doc_level']['avg_neg_logprob']#avg_max_neg_logprob
        #print(score)
        with open('llama2_data/climate+0.9/dataset_0.9.jsonl') as file1:  
            for line1 in file1:
#                 data1 = json.loads(line1)
#                 q = data1[0]['messages'][0]['content']
#                 claim1 = q.split('Claim: ')[1].split('Reference:')[0]
                claim1=line1.split(" Reference: ")[0].split("Claim: ")[1]
                if claim1.strip() == claim.strip():
                    #label=data1[0]['label']
                    label=line1.split("label: ")
                    if len(label)>1 and 'true' in label[1]: # hallucination
                        if score>=5: # hallucination
                            t+=1
                    else:# factual
                        if score<5: # factual
                            f+=1

# %%
num=184
print(t,t/(num-4))
print(f,f/(num-4))

all_num=num*2
FN=(num-t)/all_num  # FN:
print('FN',FN)

FP=(num-f)/all_num  # FP:
print('FP',FP)

TN=f/all_num  # TN:
print('TN',TN)

TP=t/all_num  # TP:
print('TP',TP)

Accuracy=TN+TP
print('Accuracy=',Accuracy)
Precision=TP/(TP+FP)
print('Precision=',Precision)
Recall=TP/(TP+FN)
print('Recall=',Recall)
F1=2*TP/(2*TP+FP+FN)
print('F1 score=',F1)
# Out:
# 171 0.95
# 20 0.1111111111111111
# FN 0.035326086956521736
# FP 0.44565217391304346
# TN 0.05434782608695652
# TP 0.46467391304347827
# Accuracy= 0.5190217391304348
# Precision= 0.5104477611940299
# Recall= 0.9293478260869565
# F1 score= 0.6589595375722543

# %%
num=350/2
print(t,t/num)
print(f,f/num)

all_num=num*2
FN=(num-t)/all_num  # FN:
print('FN',FN)

FP=(num-f)/all_num  # FP:
print('FP',FP)

TN=f/all_num  # TN:
print('TN',TN)

TP=t/all_num  # TP:
print('TP',TP)

Accuracy=TN+TP
print('Accuracy =',Accuracy)
Precision=TP/(TP+FP)
print('Precision =',Precision)
Recall=TP/(TP+FN)
print('Recall =',Recall)
F1=2*TP/(2*TP+FP+FN)
print('F1 score =',F1)
# Out:
# 53 0.3028571428571429
# 128 0.7314285714285714
# FN 0.3485714285714286
# FP 0.13428571428571429
# TN 0.3657142857142857
# TP 0.15142857142857144
# Accuracy = 0.5171428571428571
# Precision = 0.53
# Recall = 0.3028571428571429
# F1 score = 0.38545454545454544

# %% [markdown]
# ## combine

# %%
t=0
f=0
n=0
with open('baselines/SelfCk-1gm/wice/result_0.5_1.json') as file:
    for line in file:
        data = json.loads(line)
        p1 = data['p1']
        answer = data['sent_scores_mqag']
        score = answer['doc_level']['avg_neg_logprob']#avg_max_neg_logprob
        flag=False
        with open('wice+0.5/dataset_0.5.jsonl') as file1:  
            for line1 in file1:
                data1 = json.loads(line1)
                q = data1[0]['messages'][0]['content']
                ref1 = q.split('Reference:')[-1]
                sentences1=ref1.strip().split('.')
                sentences2=p1.strip()[:-1].split('.')
                if ref1.strip()==p1.strip()[:-1] or len(sentences1)>1 and len(sentences2)>1 and sentences1[-2] == sentences2[-2]:
                    flag = True
                    n+=1
                    label=data1[0]['label']
                    if label == 'true': # hallucination
                        if score>=5: # hallucination
                            t+=1
                    else:# factual
                        if score<5: # factual
                            f+=1
        if flag==False:
            with open('wice+0.5/dataset_0.5.jsonl') as file1:  
                for line1 in file1:
                    data1 = json.loads(line1)
                    q = data1[0]['messages'][0]['content']
                    ref1 = q.split('Reference:')[-1]
                    sub=ref1.strip().split('\"')
                    sub1=p1.strip()[:-1].split('\\\"')
                    if len(sub)>2 and len(sub1)>2 and sub[-2]==sub1[-2]:
                        flag = True
                        n+=1
                        label=data1[0]['label']
                        if label == 'true': # hallucination
                            if score>=5: # hallucination
                                t+=1
                        else:# factual
                            if score<5: # factual
                                f+=1
                    if flag==False:
                        if len(sub)>2 and len(sub1)>2 and len(sub1[-2].split('\\u'))>1:
                            uni=sub1[-2].split('\\u')[-1][4:]
                            length=len(uni)
                            if sub[-2].strip()[-length:] == uni:
                                flag = True
                                n+=1
                                label=data1[0]['label']
                                if label == 'true': # hallucination
                                    if score>=5: # hallucination
                                        t+=1
                                else:# factual
                                    if score<5: # factual
                                        f+=1
                    if flag==False:
                        uni=p1.strip()[:-1].split('\\u')[-1][4:]
                        length=len(uni)
                        if ref1.strip()[-length:] == uni:
                            flag = True
                            n+=1
                            label=data1[0]['label']
                            if label == 'true': # hallucination
                                if score>=5: # hallucination
                                    t+=1
                            else:# factual
                                if score<5: # factual
                                    f+=1

# %%
print(n)
# Out:
# 508

# %%
num=254
print(t,t/num)
print(f,f/num)

all_num=num*2
FN=(num-t)/all_num  # FN:
print('FN',FN)

FP=(num-f)/all_num  # FP:
print('FP',FP)

TN=f/all_num  # TN:
print('TN',TN)

TP=t/all_num  # TP:
print('TP',TP)

Accuracy=TN+TP
print('Accuracy =',Accuracy)
Precision=TP/(TP+FP)
print('Precision =',Precision)
Recall=TP/(TP+FN)
print('Recall =',Recall)
F1=2*TP/(2*TP+FP+FN)
print('F1 score =',F1)
# Out:
# 31 0.1220472440944882
# 236 0.9291338582677166
# FN 0.4389763779527559
# FP 0.03543307086614173
# TN 0.4645669291338583
# TP 0.0610236220472441
# Accuracy = 0.5255905511811023
# Precision = 0.6326530612244898
# Recall = 0.1220472440944882
# F1 score = 0.2046204620462046

# %% [markdown]
# # zero_shot_CoT
# ## temperature=0.9

# %%
t=0
f=0
n=0
with open('baselines/zero_shot_CoT/pubhealth/result_0.9.jsonl') as file:
    for line in file:
        data = json.loads(line)
        question = data[0]['messages'][1]['content']
        ref = question.split('\n[claim]: ')[-1].split('You MUST only respond in the format as described')[0]
        answer = data[1]['choices'][0]['message']['content']
        choice = answer.split('\"factuality\":')[1].strip()
        with open('pubhealth+0.9/dataset_0.9.jsonl') as file1:
            for line1 in file1:
                data1 = json.loads(line1)
                q = data1[0]['messages'][0]['content']
                ref1 = q.split('Reference:')[-1]
                if ref1.strip() == ref.strip():
                    label=data1[0]['label']
                    n+=1
                    if 'true' == label: # hallucination
                        if 'false' in choice or 'False' in choice: # hallucination
                            t+=1
                    else:# factual
                        if 'true' in choice or 'True' in choice: # factual
                            f+=1

# %%
t=0
f=0
n=0
with open('baselines/zero_shot_CoT/wice/7B/result_0.9.jsonl') as file:
    for line in file:
        ref = line.split('[reference]: ')[1].split('\\nYou MUST only respond in the format as described')[0]
        choice = line.split('\\\"factuality\\\":')[-1].strip()
        flag=False
        pre=n
        with open('llama_data/wice+0.9/dataset_0.9.jsonl') as file1:
            for line1 in file1:
                ref1=line1.split("> Assistant: ")[0].split("Reference: ")
                if len(ref1)==3:
                    ref1=ref1[1]+"Reference: "+ref1[2]
                else:
                    ref1=ref1[-1]
                ref1=ref1[:-8].strip()
                if ref1.strip() == ref.strip():
                    label=line1.split("label: ")[1]
                    n+=1
                    flag=True
                    if 'true' in label: # hallucination
                        if 'false' in choice or 'False' in choice: # hallucination
                            t+=1
                    else:# factual
                        if 'true' in choice or 'True' in choice: # factual
                            f+=1
                if flag==False:
                    # 
                    c1=ref.strip().split(".")[0]
                    c2=ref1.strip().split(".")[0]
                    if c1.strip()==c2.strip():
                        label=line1.split("label: ")[1]
                        n+=1
                        flag=True
                        if 'true' in label: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
#                 if flag==False:
#                     # 
#                     c1=ref.strip().split(".")
#                     c2=ref1.strip().split(".")
#                     if len(c1)>2 and len(c2)>2 and c1[-2]==c2[-2]:
#                         label=line1.split("label: ")[1]
#                         n+=1
#                         flag=True
#                         if 'true' in label: # hallucination
#                             if 'false' in choice or 'False' in choice: # hallucination
#                                 t+=1
#                         else:# factual
#                             if 'true' in choice or 'True' in choice: # factual
#                                 f+=1
                if flag==False:
                    # 
                    c1=ref.strip().split("\\\\")[0]
                    c2=ref1.strip().split("\\\\")[0]
                    if c1==c2:
                        label=line1.split("label: ")[1]
                        n+=1
                        flag=True
                        if 'true' in label: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
                if flag==False:
                    uni=ref.strip().split('\\u')[-1][4:]
                    length=len(uni)
                    if ref1.strip()[-length:] == uni:
                        label=line1.split("label: ")[1]
                        n+=1
                        flag=True
                        if 'true' in label: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
        if n-pre!=1:
            print(n-pre)
            print(ref)
            print()

# %%
print(n)
# Out:
# 522

# %%
num=522/2
print(t,t/num)
print(f,f/num)

all_num=num*2
FN=(num-t)/all_num  # FN:
print('FN',FN)

FP=(num-f)/all_num  # FP:
print('FP',FP)

TN=f/all_num  # TN:
print('TN',TN)

TP=t/all_num  # TP:
print('TP',TP)

Accuracy=TN+TP
print('Accuracy =',Accuracy)
Precision=TP/(TP+FP)
print('Precision =',Precision)
Recall=TP/(TP+FN)
print('Recall =',Recall)
F1=2*TP/(2*TP+FP+FN)
print('F1 score =',F1)
# Out:
# 83 0.31800766283524906
# 206 0.789272030651341
# FN 0.34099616858237547
# FP 0.1053639846743295
# TN 0.3946360153256705
# TP 0.15900383141762453
# Accuracy = 0.553639846743295
# Precision = 0.6014492753623188
# Recall = 0.31800766283524906
# F1 score = 0.4160401002506266

# %% [markdown]
# ## temperature=0.5

# %%
t=0
f=0
n=0
with open('baselines/zero_shot_CoT/pubhealth/result_0.5.jsonl') as file:
    for line in file:
        data = json.loads(line)
        question = data[0]['messages'][1]['content']
        ref = question.split('\n[claim]: ')[-1].split('You MUST only respond in the format as described')[0]
        answer = data[1]['choices'][0]['message']['content']
        choice = answer.split('\"factuality\":')[1].strip()
        with open('llama2_data/pubhealth+0.5/dataset_0.5.jsonl') as file1:
            for line1 in file1:
                data1 = json.loads(line1)
                q = data1[0]['messages'][0]['content']
                ref1 = q.split('Reference:')[-1]
                if ref1.strip() == ref.strip():
                    label=data1[0]['label']
                    n+=1
                    if 'true' == label: # hallucination
                        if 'false' in choice or 'False' in choice: # hallucination
                            t+=1
                    else:# factual
                        if 'true' in choice or 'True' in choice: # factual
                            f+=1

# %%
t=0
f=0
n=0
with open('baselines/zero_shot_CoT/wice/7B/result_0.5.jsonl') as file:
    for line in file:
        ref = line.split('[reference]: ')[1].split('\\nYou MUST only respond in the format as described')[0]
        choice = line.split('\\\"factuality\\\":')[-1].strip()
        flag=False
        pre=n
        with open('llama_data/wice+0.5/dataset_0.5.jsonl') as file1:
            for line1 in file1:
                ref1=line1.split("> Assistant: ")[0].split("Reference: ")
                if len(ref1)==3:
                    ref1=ref1[1]+"Reference: "+ref1[2]
                else:
                    ref1=ref1[-1]
                ref1=ref1[:-8].strip()
                if ref1.strip() == ref.strip():
                    label=line1.split("label: ")
                    n+=1
                    flag=True
                    if len(label)>1 and 'true' in label[1]: # hallucination
                        if 'false' in choice or 'False' in choice: # hallucination
                            t+=1
                    else:# factual
                        if 'true' in choice or 'True' in choice: # factual
                            f+=1
                if flag==False:
                    # 
                    c1=ref.strip().split(".")[0]
                    c2=ref1.strip().split(".")[0]
                    if c1.strip()==c2.strip():
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
#                 if flag==False:
#                     # 
#                     c1=ref.strip().split(".")
#                     c2=ref1.strip().split(".")
#                     if len(c1)>2 and len(c2)>2 and c1[-2]==c2[-2]:
#                         label=line1.split("label: ")
#                         n+=1
#                         flag=True
#                         if len(label)>1 and 'true' in label[1]: # hallucination
#                             if 'false' in choice or 'False' in choice: # hallucination
#                                 t+=1
#                         else:# factual
#                             if 'true' in choice or 'True' in choice: # factual
#                                 f+=1
                if flag==False:
                    # 
                    c1=ref.strip().split("\\\\")[0]
                    c2=ref1.strip().split("\\\\")[0]
                    if c1==c2:
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
                if flag==False:
                    uni=ref.strip().split('\\u')[-1][4:]
                    length=len(uni)
                    if ref1.strip()[-length:] == uni:
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
        if n-pre!=1:
            print(n-pre)
            print(ref)
            print()

# %%
print(n)
# Out:
# 486

# %%
num=486/2
print(t,t/num)
print(f,f/num)

all_num=num*2
FN=(num-t)/all_num  # FN:
print('FN',FN)

FP=(num-f)/all_num  # FP:
print('FP',FP)

TN=f/all_num  # TN:
print('TN',TN)

TP=t/all_num  # TP:
print('TP',TP)

Accuracy=TN+TP
print('Accuracy =',Accuracy)
Precision=TP/(TP+FP)
print('Precision =',Precision)
Recall=TP/(TP+FN)
print('Recall =',Recall)
F1=2*TP/(2*TP+FP+FN)
print('F1 score =',F1)
# Out:
# 64 0.26337448559670784
# 199 0.8189300411522634
# FN 0.3683127572016461
# FP 0.09053497942386832
# TN 0.4094650205761317
# TP 0.13168724279835392
# Accuracy = 0.5411522633744856
# Precision = 0.5925925925925926
# Recall = 0.26337448559670784
# F1 score = 0.36467236467236464

# %% [markdown]
# ## temperature=0.1

# %%
t=0
f=0
n=0
with open('baselines/zero_shot_CoT/climate/result_0.1.jsonl') as file:
    for line in file:
        data = json.loads(line)
        question = data[0]['messages'][1]['content']
        ref = question.split('\n[claim]: ')[-1].split('You MUST only respond in the format as described')[0]
        answer = data[1]['choices'][0]['message']['content']
        choice = answer.split('\"factuality\":')[1].strip()
        with open('climate+0.1/dataset.jsonl') as file1:
            for line1 in file1:
                data1 = json.loads(line1)
                q = data1[0]['messages'][0]['content']
                ref1 = q.split('Reference:')[-1]
                if ref1.strip() == ref.strip():
                    label=data1[0]['label']
                    n+=1
                    if 'true' == label: # hallucination
                        if 'false' in choice or 'False' in choice: # hallucination
                            t+=1
                    else:# factual
                        if 'true' in choice or 'True' in choice: # factual
                            f+=1

# %%
t=0
f=0
n=0
with open('baselines/zero_shot_CoT/pubhealth/7B/result_0.1.jsonl') as file:
    for line in file:
        ref = line.split('[reference]: ')[1].split('\\nYou MUST only respond in the format as described')[0]
        choice = line.split('\\\"factuality\\\":')[-1].strip()
        flag=False
        pre=n
        with open('llama_data/pubhealth+0.1/dataset_0.1.jsonl') as file1:
            for line1 in file1:
                ref1=line1.split("> Assistant: ")[0].split("Reference: ")
                if len(ref1)==3:
                    ref1=ref1[1]+"Reference: "+ref1[2]
                else:
                    ref1=ref1[-1]
                ref1=ref1[:-8].strip()
                if ref1.strip() == ref.strip():
                    label=line1.split("label: ")
                    n+=1
                    flag=True
                    if len(label)>1 and 'true' in label[1]: # hallucination
                        if 'false' in choice or 'False' in choice: # hallucination
                            t+=1
                    else:# factual
                        if 'true' in choice or 'True' in choice: # factual
                            f+=1
#                 if flag==False:
#                     # 
#                     c1=ref.strip().split(".")[0]
#                     c2=ref1.strip().split(".")[0]
#                     if c1.strip()==c2.strip():
#                         label=line1.split("label: ")
#                         n+=1
#                         flag=True
#                         if len(label)>1 and 'true' in label[1]: # hallucination
#                             if 'false' in choice or 'False' in choice: # hallucination
#                                 t+=1
#                         else:# factual
#                             if 'true' in choice or 'True' in choice: # factual
#                                 f+=1
                if flag==False:
                    # 
                    c1=ref.strip().split(".")
                    c2=ref1.strip().split(".")
                    if len(c1)>2 and len(c2)>2 and c1[-2]==c2[-2]:
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
                if flag==False:
                    # 
                    c1=ref.strip().split("\\\\")[0]
                    c2=ref1.strip().split("\\\\")[0]
                    if c1==c2:
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
                if flag==False:
                    uni=ref.strip().split('\\u')[-1][4:]
                    length=len(uni)
                    if ref1.strip()[-length:] == uni:
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
        if n-pre!=1:
            print(n-pre)
            print(ref)
            print()

# %%
t=0
f=0
n=0
with open('baselines/zero_shot_CoT/climate/13B/result_99.jsonl') as file:
    for line in file:
        ref = line.split('[reference]: ')[1].split('\\nYou MUST only respond in the format as described')[0]
        if "Trump's Jobs" not in ref:
            ref = ref[:-14]
        choice = line.split('\\\"factuality\\\":')[-1].strip()
        flag=False
        pre=n
        with open('llama2_data/climate+0.9/dataset_0.9.jsonl') as file1:
            for line1 in file1:
                ref1=line1.split("Response: ")[0].split("Reference: ")[1].strip()
                if "s Jobs" not in ref1:
                    ref1=ref1[:-7]
                if ref1.strip() == ref.strip():
                    label=line1.split("label: ")
                    n+=1
                    flag=True
                    if len(label)>1 and 'true' in label[1]: # hallucination
                        if 'false' in choice or 'False' in choice: # hallucination
                            t+=1
                    else:# factual
                        if 'true' in choice or 'True' in choice: # factual
                            f+=1
#                 if flag==False:
#                     # 
#                     c1=ref.strip().split(".")[0]
#                     c2=ref1.strip().split(".")[0]
#                     if c1.strip()==c2.strip():
#                         label=line1.split("label: ")
#                         n+=1
#                         flag=True
#                         if len(label)>1 and 'true' in label[1]: # hallucination
#                             if 'false' in choice or 'False' in choice: # hallucination
#                                 t+=1
#                         else:# factual
#                             if 'true' in choice or 'True' in choice: # factual
#                                 f+=1
                if flag==False:
                    # 
                    c1=ref.strip().split(".")
                    c2=ref1.strip().split(".")
                    if len(c1)>2 and len(c2)>2 and c1[-2]==c2[-2]:
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
                if flag==False:
                    # 
                    c1=ref.strip().split("\\\\n")[-1]
                    c2=ref1.strip().split("\\\\n")[-1]
                    if c1==c2:
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
                    if flag==False:
                        # 
                        c1=ref.strip().split("\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"")
                        c2=ref1.strip().split("\\\\\\\\\\\\\\\"")
                        if len(c1)>2 and len(c2)>2 and c1[1]==c2[1]:
                            label=line1.split("label: ")
                            n+=1
                            flag=True
                            if len(label)>1 and 'true' in label[1]: # hallucination
                                if 'false' in choice or 'False' in choice: # hallucination
                                    t+=1
                            else:# factual
                                if 'true' in choice or 'True' in choice: # factual
                                    f+=1
                if flag==False:
                    uni=ref.strip().split('\\u')[-1][4:]
                    length=len(uni)
                    if ref1.strip()[-length:] == uni:
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
                if flag==False:
                    if ("1991 paper by Keeling et al."in ref and "1991 paper by Keeling et al." in ref1) or ("laim is from a paper by Usoskin et a"in ref and "laim is from a paper by Usoskin et a" in ref1)or ("IPCC (Intergovernmental Panel on Climate Change) st"in ref and "IPCC (Intergovernmental Panel on Climate Change) st" in ref1)or ("ew York Times article from "in ref and "ew York Times article from " in ref1) or ("phies of notable celebrities often state that the celebri" in ref and "phies of notable celebrities often state that the celebri" in ref1) or ("The Real Inconvenient Truth" in ref and "The Real Inconvenient Truth" in ref1) or ("BBC Sport Website: The Ospreys overcame a late rally by Newcas" in ref1 and "BBC Sport Website: The Ospreys overcame a late rally by Newcas" in ref) or ("The Struggle for Women's Suffrage in" in ref and "The Struggle for Women's Suffrage in" in ref1) or "2018 Academy Awards Nominations" in ref and "2018 Academy Awards Nominations" in ref1 or "Houghton Mifflin Harcourt. De Klerk write" in ref and "Houghton Mifflin Harcourt. De Klerk write" in ref1:
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
        if n-pre!=1:
            print(n-pre)
            print(ref)
            print()
# Out:
# 2
# ...

# %%
print(t,f)
# Out:
# 79 138

# %%
print(n)
# Out:
# 371

# %%
num=368/2
print(t,t/num)
print(f,f/num)

all_num=num*2
FN=(num-t)/all_num  # FN:
print('FN',FN)

FP=(num-f)/all_num  # FP:
print('FP',FP)

TN=f/all_num  # TN:
print('TN',TN)

TP=t/all_num  # TP:
print('TP',TP)

Accuracy=TN+TP
print('Accuracy =',Accuracy)
Precision=TP/(TP+FP)
print('Precision =',Precision)
Recall=TP/(TP+FN)
print('Recall =',Recall)
F1=2*TP/(2*TP+FP+FN)
print('F1 score =',F1)
# Out:
# 29 0.15760869565217392
# 167 0.907608695652174
# FN 0.421195652173913
# FP 0.04619565217391304
# TN 0.453804347826087
# TP 0.07880434782608696
# Accuracy = 0.532608695652174
# Precision = 0.6304347826086957
# Recall = 0.15760869565217392
# F1 score = 0.25217391304347825

# %% [markdown]
# # 3_shot_CoT
# ## temperature=0.9

# %%
t=0
f=0
n=0
with open('baselines/3_shot_CoT/wice/result_0.9.jsonl') as file:
    for line in file:
        data = json.loads(line)
        question = data[0]['messages'][1]['content']
        ref = question.split('[claim]: ')[-1].split('[response]: ')[0]
        answer = data[1]['choices'][0]['message']['content']
        choice = answer.split('\"factuality\":')[1].strip()
        with open('wice+0.9/dataset_0.9.jsonl') as file1:
            for line1 in file1:
                data1 = json.loads(line1)
                q = data1[0]['messages'][0]['content']
                ref1 = q.split('Reference:')[-1]
                if ref1.strip() == ref.strip() or ref1.strip().split('.')[-2] == ref.strip().split('.')[-2]:
                    label=data1[0]['label']
                    n+=1
                    if 'true' == label: # hallucination
                        if 'false' in choice or 'False' in choice: # hallucination
                            t+=1
                    else:# factual
                        if 'true' in choice or 'True' in choice: # factual
                            f+=1

# %%
t=0
f=0
n=0
with open('baselines/3_shot_CoT/pubhealth/7B/result_0.9.jsonl') as file:
    for line in file:
        ref = line.split('[reference]: ')[-1].split('\\nYou MUST only respond in the format as described')[0]
        choice = line.split('\\\"factuality\\\":')[-1].strip()
        flag=False
        pre=n
        with open('llama_data/pubhealth+0.9/dataset_0.9.jsonl') as file1:
            for line1 in file1:
                ref1=line1.split("> Assistant: ")[0].split("Reference: ")
                if len(ref1)==3:
                    ref1=ref1[1]+"Reference: "+ref1[2]
                else:
                    ref1=ref1[-1]
                ref1=ref1[:-8].strip()
                if ref1.strip() == ref.strip():
                    label=line1.split("label: ")
                    n+=1
                    flag=True
                    if len(label)>1 and 'true' in label[1]: # hallucination
                        if 'false' in choice or 'False' in choice: # hallucination
                            t+=1
                    else:# factual
                        if 'true' in choice or 'True' in choice: # factual
                            f+=1
                if flag==False:
                    # 
                    c1=ref.strip().split(".")[0]
                    c2=ref1.strip().split(".")[0]
                    if c1.strip()==c2.strip():
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
                if flag==False:
                    # 
                    c1=ref.strip().split(".")
                    c2=ref1.strip().split(".")
                    if len(c1)>2 and len(c2)>2 and c1[-2]==c2[-2]:
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
                if flag==False:
                    # 
                    c1=ref.strip().split("\\\\")[0]
                    c2=ref1.strip().split("\\\\")[0]
                    if c1==c2:
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
                if flag==False:
                    uni=ref.strip().split('\\u')[-1][4:]
                    length=len(uni)
                    if ref1.strip()[-length:] == uni:
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
        if n-pre!=1:
            print(n-pre)
            print(ref)
            print()

# %%
with open('llama2_data/pubhealth+0.9/dataset_0.9.jsonl') as file1:
            for line1 in file1:
                ref1=line1.split("Response: ")[0].split("Reference: ")
                if len(ref1)==3:
                    ref1=ref1[1]+"Reference: "+ref1[2]
                else:
                    ref1=ref1[-1]
                ref1=ref1[:-8].strip()
                print(ref1)
# Out:
# 3 August 2018, BBC News, Germany pork ban: Schools in Berlin drop pork from menus over 'Muslim sensitivities' https://www.bbc.com/news/world-europe-45034585 The claim suggests that Germany has banned pork from school canteens to avoid offending Muslim'migrants.' According to the BBC News article, Berlin schools have dropped pork from their menus to cater to Muslim sensitivities. However, it's important to note that there is no nationwide ban on pork in Germany, and the decision to remove pork from school menus was made by individual schools in Berlin. The move was reportedly made to promote religious and cultural diversity and avoid offending Muslim students. While the decision has sparked controversy and discussions around religious tolerance and diversity, there is no evidence to suggest that it was motivated by a desire to avoid offending Muslim'migrants' specifically.
# ...

# %%
t=0
f=0
n=0
with open('baselines/3_shot_CoT/climate/13B/result_11.jsonl') as file:
    for line in file:
        ref = line.split('Result: ')[0].split('[reference]: ')[-1].split('\\nYou MUST only respond in the format as described')[0]
        choice = line.split('\\\"factuality\\\":')[-1].strip()
        flag=False
        pre=n
        with open('llama2_data/climate+0.1/dataset_0.1.jsonl') as file1:
            for line1 in file1:
                ref1=line1.split("Response: ")[0].split("Reference: ")
                if len(ref1)==3:
                    ref1=ref1[1]+"Reference: "+ref1[2]
                else:
                    ref1=ref1[1]
                ref1=ref1[:-8].strip()
                if ref1.strip() == ref.strip():
                    label=line1.split("label: ")
                    n+=1
                    flag=True
                    if len(label)>1 and 'true' in label[1]: # hallucination
                        if 'false' in choice or 'False' in choice: # hallucination
                            t+=1
                    else:# factual
                        if 'true' in choice or 'True' in choice: # factual
                            f+=1
                if flag==False:
                    # 
                    c1=ref.strip().split(".")[0]
                    c2=ref1.strip().split(".")[0]
                    if c1.strip()==c2.strip():
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
                if flag==False:
                    # 
                    c1=ref.strip().split(".")
                    c2=ref1.strip().split(".")
                    if len(c1)>2 and len(c2)>2 and c1[-2]==c2[-2]:
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
                if flag==False:
                    # 
                    c1=ref.strip().split("\\\\")[0]
                    c2=ref1.strip().split("\\\\")[0]
                    if c1==c2:
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
                if flag==False:
                    uni=ref.strip().split('\\u')[-1][4:]
                    length=len(uni)
                    if ref1.strip()[-length:] == uni:
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
                if flag==False:
                    if ("port from the National Institute on Aging found that many assiste" in ref and "port from the National Institute on Aging found that many assiste" in ref1):
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
        if n-pre!=1:
            print(n-pre)
            print(ref)
            print()

# %%
print(n)
# Out:
# 342

# %%
num=342/2
print(t,t/num)
print(f,f/num)

all_num=num*2
FN=(num-t)/all_num  # FN:
print('FN',FN)

FP=(num-f)/all_num  # FP:
print('FP',FP)

TN=f/all_num  # TN:
print('TN',TN)

TP=t/all_num  # TP:
print('TP',TP)

Accuracy=TN+TP
print('Accuracy =',Accuracy)
Precision=TP/(TP+FP)
print('Precision =',Precision)
Recall=TP/(TP+FN)
print('Recall =',Recall)
F1=2*TP/(2*TP+FP+FN)
print('F1 score =',F1)
# Out:
# 80 0.4678362573099415
# 17 0.09941520467836257
# FN 0.26608187134502925
# FP 0.4502923976608187
# TN 0.049707602339181284
# TP 0.23391812865497075
# Accuracy = 0.283625730994152
# Precision = 0.3418803418803419
# Recall = 0.4678362573099415
# F1 score = 0.39506172839506176

# %% [markdown]
# ## temperature=0.5

# %%
t=0
f=0
n=0
with open('baselines/3_shot_CoT/wice/result_0.5.jsonl') as file:
    for line in file:
        data = json.loads(line)
        question = data[0]['messages'][1]['content']
        ref = question.split('\n[claim]:  ')[-1].split('[response]: ')[0]
        answer = data[1]['choices'][0]['message']['content']
        choice = answer.split('\"factuality\":')[1].strip()
        with open('wice+0.5/dataset_0.5.jsonl') as file1:
            for line1 in file1:
                data1 = json.loads(line1)
                q = data1[0]['messages'][0]['content']
                ref1 = q.split('Reference:')[-1]
                if ref1.strip() == ref.strip():
                    label=data1[0]['label']
                    n+=1
                    if 'true' == label: # hallucination
                        if 'false' in choice or 'False' in choice: # hallucination
                            t+=1
                    else:# factual
                        if 'true' in choice or 'True' in choice: # factual
                            f+=1

# %%
t=0
f=0
n=0
with open('baselines/3_shot_CoT/pubhealth/7B/result_0.5.jsonl') as file:
    for line in file:
        ref = line.split('[reference]: ')[-1].split('\\nYou MUST only respond in the format as described')[0]
        choice = line.split('\\\"factuality\\\":')[-1].strip()
        flag=False
        pre=n
        with open('llama_data/pubhealth+0.5/dataset_0.5.jsonl') as file1:
            for line1 in file1:
                ref1=line1.split("> Assistant: ")[0].split("Reference: ")
                if len(ref1)==3:
                    ref1=ref1[1]+"Reference: "+ref1[2]
                else:
                    ref1=ref1[-1]
                ref1=ref1[:-8].strip()
                if ref1.strip() == ref.strip():
                    label=line1.split("label: ")
                    n+=1
                    flag=True
                    if len(label)>1 and 'true' in label[1]: # hallucination
                        if 'false' in choice or 'False' in choice: # hallucination
                            t+=1
                    else:# factual
                        if 'true' in choice or 'True' in choice: # factual
                            f+=1
                if flag==False:
                    # 
                    c1=ref.strip().split(".")[0]
                    c2=ref1.strip().split(".")[0]
                    if c1.strip()==c2.strip():
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
                if flag==False:
                    # 
                    c1=ref.strip().split(".")
                    c2=ref1.strip().split(".")
                    if len(c1)>2 and len(c2)>2 and c1[-2]==c2[-2]:
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
                if flag==False:
                    # 
                    c1=ref.strip().split("\\\\")[0]
                    c2=ref1.strip().split("\\\\")[0]
                    if c1==c2:
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
                if flag==False:
                    uni=ref.strip().split('\\u')[-1][4:]
                    length=len(uni)
                    if ref1.strip()[-length:] == uni:
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
        if n-pre!=1:
            print(n-pre)
            print(ref)
            print()

# %%
print(n)
# Out:
# 442

# %%
num=221
print(t,t/num)
print(f,f/num)

all_num=num*2
FN=(num-t)/all_num  # FN:
print('FN',FN)

FP=(num-f)/all_num  # FP:
print('FP',FP)

TN=f/all_num  # TN:
print('TN',TN)

TP=t/all_num  # TP:
print('TP',TP)

Accuracy=TN+TP
print('Accuracy =',Accuracy)
Precision=TP/(TP+FP)
print('Precision =',Precision)
Recall=TP/(TP+FN)
print('Recall =',Recall)
F1=2*TP/(2*TP+FP+FN)
print('F1 score =',F1)
# Out:
# 89 0.40271493212669685
# 157 0.7104072398190046
# FN 0.2986425339366516
# FP 0.14479638009049775
# TN 0.3552036199095023
# TP 0.20135746606334842
# Accuracy = 0.5565610859728507
# Precision = 0.5816993464052288
# Recall = 0.40271493212669685
# F1 score = 0.4759358288770053

# %% [markdown]
# ## temperature=0.1

# %%
t=0
f=0
n=0
with open('baselines/3_shot_CoT/wice/result_0.1.jsonl') as file:
    for line in file:
        data = json.loads(line)
        question = data[0]['messages'][1]['content']
        ref = question.split('\n[claim]:  ')[-1].split('[response]: ')[0]
        answer = data[1]['choices'][0]['message']['content']
        choice = answer.split('\"factuality\":')[1].strip()
        with open('wice+0.1/dataset_0.1.jsonl') as file1:
            for line1 in file1:
                data1 = json.loads(line1)
                q = data1[0]['messages'][0]['content']
                ref1 = q.split('Reference:')[-1]
                if ref1.strip() == ref.strip():
                    label=data1[0]['label']
                    n+=1
                    if 'true' == label: # hallucination
                        if 'false' in choice or 'False' in choice: # hallucination
                            t+=1
                    else:# factual
                        if 'true' in choice or 'True' in choice: # factual
                            f+=1

# %%
t=0
f=0
n=0
with open('baselines/3_shot_CoT/pubhealth/7B/result_0.1.jsonl') as file:
    for line in file:
        ref = line.split('[reference]: ')[-1].split('\\nYou MUST only respond in the format as described')[0]
        choice = line.split('\\\"factuality\\\":')[-1].strip()
        flag=False
        pre=n
        with open('llama_data/pubhealth+0.1/dataset_0.1.jsonl') as file1:
            for line1 in file1:
                ref1=line1.split("> Assistant: ")[0].split("Reference: ")
                if len(ref1)==3:
                    ref1=ref1[1]+"Reference: "+ref1[2]
                else:
                    ref1=ref1[-1]
                ref1=ref1[:-8].strip()
                if ref1.strip() == ref.strip():
                    label=line1.split("label: ")
                    n+=1
                    flag=True
                    if len(label)>1 and 'true' in label[1]: # hallucination
                        if 'false' in choice or 'False' in choice: # hallucination
                            t+=1
                    else:# factual
                        if 'true' in choice or 'True' in choice: # factual
                            f+=1
                if flag==False:
                    # 
                    c1=ref.strip().split(".")[0]
                    c2=ref1.strip().split(".")[0]
                    if c1.strip()==c2.strip():
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
                if flag==False:
                    # 
                    c1=ref.strip().split(".")
                    c2=ref1.strip().split(".")
                    if len(c1)>2 and len(c2)>2 and c1[-2]==c2[-2]:
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
                if flag==False:
                    # 
                    c1=ref.strip().split("\\\\")[0]
                    c2=ref1.strip().split("\\\\")[0]
                    if c1==c2:
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
                if flag==False:
                    uni=ref.strip().split('\\u')[-1][4:]
                    length=len(uni)
                    if ref1.strip()[-length:] == uni:
                        label=line1.split("label: ")
                        n+=1
                        flag=True
                        if len(label)>1 and 'true' in label[1]: # hallucination
                            if 'false' in choice or 'False' in choice: # hallucination
                                t+=1
                        else:# factual
                            if 'true' in choice or 'True' in choice: # factual
                                f+=1
        if n-pre!=1:
            print(n-pre)
            print(ref)
            print()

# %%
print(n)
# Out:
# 432

# %%
num=432/2
print(t,t/num)
print(f,f/num)

all_num=num*2
FN=(num-t)/all_num  # FN:
print('FN',FN)

FP=(num-f)/all_num  # FP:
print('FP',FP)

TN=f/all_num  # TN:
print('TN',TN)

TP=t/all_num  # TP:
print('TP',TP)

Accuracy=TN+TP
print('Accuracy =',Accuracy)
Precision=TP/(TP+FP)
print('Precision =',Precision)
Recall=TP/(TP+FN)
print('Recall =',Recall)
F1=2*TP/(2*TP+FP+FN)
print('F1 score =',F1)
# Out:
# 75 0.3472222222222222
# 151 0.6990740740740741
# FN 0.3263888888888889
# FP 0.15046296296296297
# TN 0.34953703703703703
# TP 0.1736111111111111
# Accuracy = 0.5231481481481481
# Precision = 0.5357142857142857
# Recall = 0.3472222222222222
# F1 score = 0.42134831460674155
